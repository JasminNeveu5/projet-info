# %% [markdown]
# # Playground
#
# This is a playground for testing and experimenting with the code.

# %%
from src.analysis.pandas.driverRankingYear import get_ranking_year

for driver in get_ranking_year(2022):
    print(driver)
    print("\n")
# Out:
# Forename: Max
# Surname: Verstappen
# Nationality: Dutch
# total_points: 454.0
# grand_prix_points: 433.0
# sprint_points: 21.0
# mt_points: 5
#
#
# Forename: Charles
# Surname: Leclerc
# Nationality: Monegasque
# total_points: 308.0
# grand_prix_points: 291.0
# sprint_points: 17.0
# mt_points: 3
#
#
# Forename: Sergio
# Surname: Pérez
# Nationality: Mexican
# total_points: 305.0
# grand_prix_points: 291.0
# sprint_points: 14.0
# mt_points: 4
#
#
# Forename: George
# Surname: Russell
# Nationality: British
# total_points: 275.0
# grand_prix_points: 262.0
# sprint_points: 13.0
# mt_points: 3
#
#
# Forename: Carlos
# Surname: Sainz
# Nationality: Spanish
# total_points: 246.0
# grand_prix_points: 228.0
# sprint_points: 18.0
# mt_points: 2
#
#
# Forename: Lewis
# Surname: Hamilton
# Nationality: British
# total_points: 240.0
# grand_prix_points: 233.0
# sprint_points: 7.0
# mt_points: 2
#
#
# Forename: Lando
# Surname: Norris
# Nationality: British
# total_points: 122.0
# ...
