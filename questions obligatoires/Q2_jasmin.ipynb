# %% [markdown]
#  # Question 2 : Quel était le classement des pilotes à l'issue de la saison 2023 ? Gérer les cas d'égalité (nombre de victoires, deuxièmes places, etc.).

# %%
import pandas as pd
results = pd.read_csv("../data/results.csv")
races = pd.read_csv("../data/races.csv")
drivers = pd.read_csv("../data/drivers.csv")
# Out:
#    driverId   driverRef number code  forename     surname         dob  \
# 0         1    hamilton     44  HAM     Lewis    Hamilton  1985-01-07
# 1         2    heidfeld     \N  HEI      Nick    Heidfeld  1977-05-10
# 2         3     rosberg      6  ROS      Nico     Rosberg  1985-06-27
# 3         4      alonso     14  ALO  Fernando      Alonso  1981-07-29
# 4         5  kovalainen     \N  KOV    Heikki  Kovalainen  1981-10-19
#
#   nationality                                             url
# 0     British     http://en.wikipedia.org/wiki/Lewis_Hamilton
# 1      German      http://en.wikipedia.org/wiki/Nick_Heidfeld
# 2      German       http://en.wikipedia.org/wiki/Nico_Rosberg
# 3     Spanish    http://en.wikipedia.org/wiki/Fernando_Alonso
# 4     Finnish  http://en.wikipedia.org/wiki/Heikki_Kovalainen

# %%
races_2023 = pd.merge(results,races[races["year"] == 2023], on="raceId")
races_2023['positionOrder'] = races_2023['positionOrder'].astype(int)
points_wins = races_2023.groupby('driverId').agg({'points': 'sum', 'positionOrder': lambda x: (x == 1).sum(), 'positionOrder': lambda x: (x == 2).sum(), 'positionOrder': lambda x: (x == 3).sum()}).reset_index()
points_wins.columns = ['driverId', 'points', 'wins', 'second_places', 'third_places']
sorted_drivers = points_wins.sort_values(by=['points', 'wins', 'second_places', 'third_places'], ascending=[False, False, False, False])
pd.merge(sorted_drivers, drivers, on='driverId')[['forename', 'surname', 'points']]
# Out:
#      forename     surname  points
# 0         Max  Verstappen   530.0
# 1      Sergio       Pérez   260.0
# 2       Lewis    Hamilton   217.0
# 3    Fernando      Alonso   198.0
# 4     Charles     Leclerc   185.0
# 5       Lando      Norris   184.0
# 6      Carlos       Sainz   178.0
# 7      George     Russell   157.0
# 8       Oscar     Piastri    82.0
# 9       Lance      Stroll    68.0
# 10    Esteban        Ocon    56.0
# 11     Pierre       Gasly    54.0
# 12  Alexander       Albon    25.0
# 13       Yuki     Tsunoda    14.0
# 14   Valtteri      Bottas    10.0
# 15       Nico  Hülkenberg     6.0
# 16     Daniel   Ricciardo     6.0
# 17     Guanyu        Zhou     6.0
# 18      Kevin   Magnussen     3.0
# 19       Liam      Lawson     2.0
# 20      Logan    Sargeant     1.0
# 21       Nyck    de Vries     0.0

# %% [markdown]
# one-liner pour l'api

# %%
races_year = pd.merge(results, races[races["year"] == 2014], on="raceId")
races_year["positionOrder"] = races_year["positionOrder"].astype(int)
points_wins = (
    races_year.groupby("driverId")
    .agg(
        {
            "points": "sum",
            "positionOrder": lambda x: (x == 1).sum(),
            "positionOrder": lambda x: (x == 2).sum(),
            "positionOrder": lambda x: (x == 3).sum(),
        }
        points=("points", "sum"),
        wins=("positionOrder", lambda x: (x == 1).sum()),
        second_places=("positionOrder", lambda x: (x == 2).sum()),
        third_places=("positionOrder", lambda x: (x == 3).sum()),
    )
    .reset_index()
)
points_wins.columns = [
    "driverId",
    "points",
    "wins",
    "second_places",
    "third_places",
]
sorted_drivers = points_wins.sort_values(
    by=["points", "wins", "second_places", "third_places"],
    ascending=[False, False, False, False],
)

pd.merge(sorted_drivers, drivers, on="driverId")[
        ["forename", "surname", "points"]
    ].to_json(orient="records")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[14], line 15
#       2 races_year["positionOrder"] = races_year["positionOrder"].astype(int)
#       3 points_wins = (
#       4     races_year.groupby("driverId")
#       5     .agg(
#    (...)     13     .reset_index()
#      14 )
# ---> 15 points_wins.columns = [
#      16     "driverId",
#      17     "points",
#      18     "wins",
#      19     "second_places",
#      20     "third_places",
#      21 ]
#      22 sorted_drivers = points_wins.sort_values(
#      23     by=["points", "wins", "second_places", "third_places"],
#      24     ascending=[False, False, False, False],
#      25 )
#      27 pd.merge(sorted_drivers, drivers, on="driverId")[
#      28         ["forename", "surname", "points"]
#      29     ].to_json(orient="records")
#
# File ~/.pyenv/versions/3.13.1/lib/python3.13/site-packages/pandas/core/internals/managers.py:238, in BaseBlockManager.set_axis(self, axis, new_labels)
#     236 def set_axis(self, axis: AxisInt, new_labels: Index) -> None:
#     237     # Caller is responsible for ensuring we have an Index object.
# --> 238     self._validate_set_axis(axis, new_labels)
#     239     self.axes[axis] = new_labels
#
# File ~/.pyenv/versions/3.13.1/lib/python3.13/site-packages/pandas/core/internals/base.py:98, in DataManager._validate_set_axis(self, axis, new_labels)
#      95     pass
#      97 elif new_len != old_len:
# ---> 98     raise ValueError(
#      99         f"Length mismatch: Expected axis has {old_len} elements, new "
#     100         f"values have {new_len} elements"
#     101     )
#
# ValueError: Length mismatch: Expected axis has 3 elements, new values have 5 elements
